# %% [markdown]
# # turtle로 원 및 정다각형 그리기

# %% [markdown]
# * colab 에서는 turtle 을 사용할 수 없어서
# * 비슷한 기능이 있는 ColabTurtlePlus을 설치해서 사용함

# %% [markdown]
#  ## colab에 ColabTurtlePlus을 설치하기

# %%
# %%capture
# !pip install ColabTurtlePlus

# %% [markdown]
# ## 실행 코드 작성하기

# %% [markdown]
# * 아래 코드 셀의 import 문은 IDLE에서는 import turtle 로 해야 함

# %% [markdown]
# ### 첫 번째 실행

# %%
import ColabTurtlePlus.Turtle as turtle

radius = int(input('반지름:'))
stype = int(input('도형 종류: '))
outer = int(input('바깥 원(1:O, 0:X)'))

if stype in [3, 4, 5, 6]:
    t.circle(radius, steps=stype)
if outer ==1:
    t.circle(radius )
t.done()
# Out:
#       <svg width="300" height="300">
#         <rect width="100%" height="100%" style="fill:white;stroke:gray;stroke-width:1"/>
#
#
#         <line x1="150.0" y1="150.0" x2="193.301" y2="75.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="193.301" y1="75.0" x2="106.698" y2="75.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="106.698" y1="75.0" x2="149.999" y2="150.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><path d="M 149.999 150.0 A 50 50 0 0 0 149.999 50.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 149.999 50.0 A 50 50 0 0 0 149.999 150.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/>
#
#
#         <g id="classic" visibility="visible" transform="rotate(-90.0,149.999,150.0) translate(149.999, 150.0)">
# <polygon points="-5,-4.5 0,-2.5 5,-4.5 0,4.5" transform="skewX(0) scale(1,1)" style="stroke:black;fill:black;stroke-width:1" />
# </g>
#       </svg>

# %% [markdown]
# ### 뒤 번째 실행

# %%
import ColabTurtlePlus.Turtle as turtle

radius = int(input('반지름:'))
stype = int(input('도형 종류: '))
outer = int(input('바깥 원(1:O, 0:X)'))

if stype in [3, 4, 5, 6]:
    t.circle(radius, steps=stype)
if outer ==1:
    t.circle(radius )
t.done()
# Out:
# 반지름:50
# 도형 종류: 6
# 바깥 원(1:O, 0:X)0
#       <svg width="300" height="300">
#         <rect width="100%" height="100%" style="fill:white;stroke:gray;stroke-width:1"/>
#
#
#         <line x1="150.0" y1="150.0" x2="193.301" y2="75.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="193.301" y1="75.0" x2="106.698" y2="75.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="106.698" y1="75.0" x2="149.999" y2="150.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><path d="M 149.999 150.0 A 50 50 0 0 0 149.999 50.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 149.999 50.0 A 50 50 0 0 0 149.999 150.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><line x1="149.999" y1="150.0" x2="193.3" y2="125.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="193.3" y1="125.0" x2="193.3" y2="75.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="193.3" y1="75.0" x2="149.999" y2="50.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="149.999" y1="50.0" x2="106.698" y2="75.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="106.698" y1="75.0" x2="106.698" y2="125.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="106.698" y1="125.0" x2="149.999" y2="150.0" stroke-linecap="round" style="stroke:black;stroke-width:1" />
#
#
#         <g id="classic" visibility="visible" transform="rotate(-90.0,149.999,150.0) translate(149.999, 150.0)">
# <polygon points="-5,-4.5 0,-2.5 5,-4.5 0,4.5" transform="skewX(0) scale(1,1)" style="stroke:black;fill:black;stroke-width:1" />
# </g>
#       </svg>
