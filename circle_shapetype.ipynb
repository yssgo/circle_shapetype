# %% [markdown]
# # turtle로 원 및 정다각형 그리기

# %% [markdown]
# * colab 에서는 turtle 을 사용할 수 없어서
# * 비슷한 기능이 있는 ColabTurtlePlus을 설치해서 사용함

# %% [markdown]
#  ## colab에 ColabTurtlePlus을 설치하기

# %%
# %%capture
# !pip install ColabTurtlePlus

# %% [markdown]
# ## 실행 코드 작성하기

# %% [markdown]
# * 아래 코드 셀의 import 문은 IDLE에서는 import turtle 로 해야 함

# %% [markdown]
# ### 첫 번째 실행

# %%
import ColabTurtlePlus.Turtle as turtle

t = turtle
t.clearscreen() # IDLE 에서는 이 줄 제거

radius = int(input('반지름:'))
stype = int(input('도형 종류: '))
outer = int(input('바깥 원(1:O, 0:X)'))

t.setup(200,200) # IDLE 에서는 이 줄 제거
if stype in [3, 4, 5, 6]:
    t.circle(radius, steps=stype)
if outer ==1:
    t.circle(radius )
t.done()
# Out:
# 반지름:50
# 도형 종류: 3
# 바깥 원(1:O, 0:X)1
#       <svg width="200" height="200">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <line x1="100.0" y1="100.0" x2="143.301" y2="25.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="143.301" y1="25.0" x2="56.698" y2="25.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="56.698" y1="25.0" x2="99.999" y2="100.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><path d="M 99.999 100.0 A 50 50 0 0 0 99.999 0.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 99.999 0.0 A 50 50 0 0 0 99.999 100.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/>
#
#
#         <g id="classic" visibility="visible" transform="rotate(-90.0,99.999,100.0) translate(99.999, 100.0)">
# ...

# %% [markdown]
# ### 두 번째 실행

# %%
import ColabTurtlePlus.Turtle as turtle

t = turtle
t.clearscreen() # IDLE 에서는 이 줄 제거

radius = int(input('반지름:'))
stype = int(input('도형 종류: '))
outer = int(input('바깥 원(1:O, 0:X)'))

t.setup(200,200) # IDLE 에서는 이 줄 제거
if stype in [3, 4, 5, 6]:
    t.circle(radius, steps=stype)
if outer ==1:
    t.circle(radius )
t.done()
# Out:
# 반지름:50
# 도형 종류: 6
# 바깥 원(1:O, 0:X)0
#       <svg width="200" height="200">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <line x1="100.0" y1="100.0" x2="143.301" y2="75.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="143.301" y1="75.0" x2="143.301" y2="25.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="143.301" y1="25.0" x2="100.0" y2="-0.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="100.0" y1="-0.0" x2="56.699" y2="25.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="56.699" y1="25.0" x2="56.699" y2="75.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="56.699" y1="75.0" x2="100.0" y2="100.0" stroke-linecap="round" style="stroke:black;stroke-width:1" />
#
#
#         <g id="classic" visibility="visible" transform="rotate(-90.0,100.0,100.0) translate(100.0, 100.0)">
# ...
